# %%
# %matplotlib inline
import numpy as np
import pandas as pd
from pathlib import Path

import matplotlib.pyplot as plt
import seaborn as sb

from matplotlib import style

# %%
train_df = pd.read_csv(Path('Resources/2019loans.csv'))

# %%
pd.set_option("display.max_columns", None)

# %%
train_df.head()  #2019 loans
# Out:
#    Unnamed: 0   index  loan_amnt  int_rate  installment home_ownership  \
# 0       57107   57107    13375.0    0.1797       483.34       MORTGAGE
# 1      141451  141451    21000.0    0.1308       478.68       MORTGAGE
# 2      321143  321143    20000.0    0.1240       448.95       MORTGAGE
# 3       11778   11778     3000.0    0.1240       100.22           RENT
# 4      169382  169382    30000.0    0.1612      1056.49       MORTGAGE
#
#    annual_inc verification_status loan_status pymnt_plan    dti  delinq_2yrs  \
# 0    223000.0        Not Verified    low_risk          n  29.99          0.0
# 1    123000.0     Source Verified    low_risk          n  11.26          2.0
# 2    197000.0     Source Verified    low_risk          n  11.28          0.0
# 3     45000.0        Not Verified    low_risk          n  18.08          0.0
# 4    133000.0     Source Verified    low_risk          n  27.77          0.0
#
#    inq_last_6mths  open_acc  pub_rec  revol_bal  total_acc  \
# ...

# %%
train_df_converted = pd.get_dummies(train_df)
y = train_df_converted['loan_status_high_risk']
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 12175    1
# 12176    1
# 12177    1
# 12178    1
# 12179    1
# Name: loan_status_high_risk, Length: 12180, dtype: uint8

# %%
X=train_df_converted.drop(['loan_status_high_risk', 'loan_status_low_risk'], axis=1)

# %%
X = train_df_converted.iloc[:,:]  #independent columns
#y = data.iloc[:,-1]    #target column i.e price range
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
model = ExtraTreesClassifier()
model.fit(X,y)
print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()
# Out:
# [5.50249910e-03 6.89597506e-03 1.10477200e-03 8.32422855e-03
#  1.70835203e-03 4.77772687e-04 4.38696678e-04 3.31600336e-04
#  7.15253065e-04 4.43962399e-04 2.51082921e-04 5.10140999e-04
#  5.40443378e-04 2.20127917e-03 2.36201790e-03 2.59085638e-03
#  3.20850307e-03 3.30817319e-03 4.76752994e-03 1.85575199e-03
#  0.00000000e+00 0.00000000e+00 2.58646219e-03 1.87200308e-04
#  0.00000000e+00 2.05761095e-06 3.49875846e-04 4.38401495e-04
#  6.32286799e-04 4.18798169e-04 4.78816115e-04 5.22476749e-04
#  5.04016300e-04 4.17446615e-04 5.19467938e-04 5.79447612e-04
#  5.51043187e-04 6.32322118e-04 5.40462923e-04 4.52790540e-04
#  6.10159914e-04 5.60821994e-04 5.65092128e-04 7.48607399e-04
#  4.14256058e-04 5.53160761e-04 6.23157838e-04 6.42225792e-05
#  0.00000000e+00 5.29614486e-04 7.97554123e-04 4.67886860e-04
#  5.39785702e-04 6.62803393e-04 5.53215815e-04 1.05855932e-03
#  3.72454284e-04 4.96163284e-04 4.76399577e-04 4.31698220e-04
# ...

# %%
X = train_df_converted[['total_pymnt', 'total_rec_late_fee','total_pymnt_inv','total_rec_prncp', 'total_rec_int', 'int_rate', 'index']]
X
# Out:
#        total_pymnt  total_rec_late_fee  total_pymnt_inv  total_rec_prncp  \
# 0           953.33                 0.0           953.33           570.34
# 1         10037.02                 0.0         10037.02          5847.03
# 2          6971.52                 0.0          6971.52          4275.77
# 3            81.63                 0.0            81.63            69.23
# 4         14763.99                 0.0         14763.99          9221.97
# ...            ...                 ...              ...              ...
# 12175      7181.35                 0.0          7181.35          3669.84
# 12176      5200.43                 0.0          5200.43          2590.02
# 12177      1571.64                 0.0          1571.64           929.57
# 12178      5225.14                 0.0          5225.14          4172.01
# 12179      7209.64                 0.0          7209.64          4383.48
#
#        total_rec_int  int_rate   index
# 0             382.99    0.1797   57107
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
from sklearn.metrics import confusion_matrix, classification_report

# %%
X_train
# Out:
#        total_pymnt  total_rec_late_fee  total_pymnt_inv  total_rec_prncp  \
# 4864       1585.04                 0.0          1585.04           899.85
# 2089       3469.46                 0.0          3469.46          2871.85
# 3344       7691.34                 0.0          7691.34          4692.26
# 11352      3343.66                 0.0          3343.66          2115.14
# 10158      4308.75                 0.0          4308.75           941.89
# ...            ...                 ...              ...              ...
# 11964      2644.43                 0.0          2644.43          1779.17
# 5191       1728.40                 0.0          1728.40          1465.40
# 5390       5314.23                 0.0          5314.23          3744.83
# 860        4618.45                 0.0          4618.45          3731.76
# 7270      17357.80                 0.0         17357.80         14633.43
#
#        total_rec_int  int_rate   index
# 4864          685.19    0.1992   61576
# ...

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier
# Out:
# LogisticRegression()

# %%
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
print(f"Training Data Score: {classifier.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.6174055829228243
# Testing Data Score: 0.6059113300492611

# %%
# import numpy as np
# new_data = np.array([[-2, 6]])
# plt.scatter(X[:, 0], X[:, 1], c=y)
# plt.scatter(new_data[0, 0], new_data[0, 1], c="r", marker="o", s=100)

# %%
from sklearn.metrics import confusion_matrix

y_true = y_test
y_pred = classifier.predict(X_test)
cm=confusion_matrix(y_true, y_pred)
cm
# Out:
# array([[ 686,  855],
#        [ 345, 1159]], dtype=int64)

# %%
predictions = classifier.predict(X_test)
pd.DataFrame({"Prediction": predictions, "Actual": y_test})
# Out:
#       Prediction  Actual
# 4767           1       0
# 8968           1       1
# 1139           1       0
# 2372           0       0
# 7899           0       1
# ...          ...     ...
# 3101           1       0
# 8086           1       1
# 4609           1       0
# 3919           0       0
# 6392           1       1
#
# [3045 rows x 2 columns]

# %%
tn, fp, fn, tp = cm.ravel()
tp
# Out:
# 1159

# %%
precision = tp/(tp+fp)
precision
# Out:
# 0.5754716981132075

# %%
sensitivity = tp/(tp+fn)
sensitivity
# Out:
# 0.7706117021276596

# %%
f_score=2*precision*sensitivity/(precision+sensitivity)
f_score
# Out:
# 0.6588971006253553

# %%
print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.45      0.53      1541
#            1       0.58      0.77      0.66      1504
#
#     accuracy                           0.61      3045
#    macro avg       0.62      0.61      0.60      3045
# weighted avg       0.62      0.61      0.60      3045

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
print('Weight coefficients: ', model.coef_)
print('y-axis intercept: ', model.intercept_)
# Out:
# Weight coefficients:  [-7.43406430e+00  7.43775103e+00  4.55791234e-04  7.43358773e+00
#   7.43365285e+00  1.03451049e+00  7.68493491e-07]
# y-axis intercept:  0.1777609697819571

# %%
# Convert categorical data to numeric and separate target feature for training data
# train_df_converted = pd.get_dummies(train_df)
# train_df_converted
# y = train_df_converted['loan_status_high_risk']
# y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 12175    1
# 12176    1
# 12177    1
# 12178    1
# 12179    1
# Name: loan_status_high_risk, Length: 12180, dtype: uint8

# %%
# Convert categorical data to numeric and separate target feature for testing data
test_df_converted = pd.get_dummies(test_df)
test_df_converted
y = test_df_converted['loan_status_high_risk']
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 4697    1
# 4698    1
# 4699    1
# 4700    1
# 4701    1
# Name: loan_status_high_risk, Length: 4702, dtype: uint8

# %%
train_df_converted
# Out:
#        Unnamed: 0   index  loan_amnt  int_rate  installment  annual_inc  \
# 0           57107   57107    13375.0    0.1797       483.34    223000.0
# 1          141451  141451    21000.0    0.1308       478.68    123000.0
# 2          321143  321143    20000.0    0.1240       448.95    197000.0
# 3           11778   11778     3000.0    0.1240       100.22     45000.0
# 4          169382  169382    30000.0    0.1612      1056.49    133000.0
# ...           ...     ...        ...       ...          ...         ...
# 12175      354912  354912    19975.0    0.2565       801.09     28000.0
# 12176      354944  354944    15000.0    0.1774       540.34     50000.0
# 12177      354973  354973     3600.0    0.1862       131.28     60000.0
# 12178      355002  355002    15000.0    0.0881       475.68     62000.0
# 12179      355307  355307    15000.0    0.1774       540.34     54080.0
#
#          dti  delinq_2yrs  inq_last_6mths  open_acc  pub_rec  revol_bal  \
# ...

# %%
test_df_converted
# Out:
#       Unnamed: 0  index  loan_amnt  int_rate  installment  annual_inc    dti  \
# 0          67991  67991    40000.0    0.0819       814.70    140000.0  19.75
# 1          25429  25429     6000.0    0.1524       208.70     55000.0  11.52
# 2          38496  38496     3600.0    0.1695       128.27     42000.0   6.74
# 3          19667  19667    20000.0    0.1524       478.33    100000.0  12.13
# 4          37505  37505     3600.0    0.1240       120.27     50000.0  16.08
# ...          ...    ...        ...       ...          ...         ...    ...
# 4697       77282  77282    30000.0    0.1240       673.42    140480.0  15.74
# 4698       77291  77291    24000.0    0.0756       747.22     50000.0  26.81
# 4699       77292  77292    10000.0    0.2305       387.36     33000.0  38.51
# 4700       77297  77297     8000.0    0.1862       205.86     38000.0  16.36
# 4701       77304  77304    30000.0    0.2055      1123.34    180000.0  12.06
#
# ...

# %%
common_columns = [col for col in train_df_converted.columns if col not in test_df_converted.columns]
common_columns
#print(len(common_columns))
# Out:
# ['debt_settlement_flag_Y']

# %%
# add missing dummy variables to testing set
test_df_converted['debt_settlement_flag_Y'] = 0
test_df_converted
# Out:
#       Unnamed: 0  index  loan_amnt  int_rate  installment  annual_inc    dti  \
# 0          67991  67991    40000.0    0.0819       814.70    140000.0  19.75
# 1          25429  25429     6000.0    0.1524       208.70     55000.0  11.52
# 2          38496  38496     3600.0    0.1695       128.27     42000.0   6.74
# 3          19667  19667    20000.0    0.1524       478.33    100000.0  12.13
# 4          37505  37505     3600.0    0.1240       120.27     50000.0  16.08
# ...          ...    ...        ...       ...          ...         ...    ...
# 4697       77282  77282    30000.0    0.1240       673.42    140480.0  15.74
# 4698       77291  77291    24000.0    0.0756       747.22     50000.0  26.81
# 4699       77292  77292    10000.0    0.2305       387.36     33000.0  38.51
# 4700       77297  77297     8000.0    0.1862       205.86     38000.0  16.36
# 4701       77304  77304    30000.0    0.2055      1123.34    180000.0  12.06
#
# ...

# %%
# Train the Logistic Regression model on the unscaled data and print the model score
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
model=LinearRegression()
mode.fit()

# %%
# Train a Random Forest Classifier model and print the model score

# %%
# Scale the data

# %%
# Train the Logistic Regression model on the scaled data and print the model score

# %%
# Train a Random Forest Classifier model on the scaled data and print the model score
